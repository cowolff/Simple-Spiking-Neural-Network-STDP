# %%
import pandas as pd
import numpy as np
import imageio
import os
from os import path
import time
import math
import random
# import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %%
ann_result = [(16, 0.3139), (24, 0.5125), (32, 0.6165), (48, 0.8791), (64, 0.9187), (96, 0.9407), (128, 0.9584), (256, 0.9808), (512, 0.9995)]

# %%
result = [{'Neurons': 50, 'Accuracy': [0.44]}, {'Neurons': 100, 'Accuracy': [0.51]}, {'Neurons': 200, 'Accuracy': [0.5]}, {'Neurons': 400, 'Accuracy': [0.55]}, {'Neurons': 800, 'Accuracy': [0.58]}]

# %%
x = [e["Accuracy"][0] for e in result]
y = [e["Neurons"] for e in result]

x2 = [e[0] for e in ann_result]
y2 = [e[1] for e in ann_result]

# %%
plt.figure(figsize=(10, 6))
plt.title("Comparison SNNs and ANNs by layer size")
plt.ylabel('Accuracy')
plt.xlabel('Layer size')
plt.plot(y, x, label="SNN")
plt.plot(x2, y2, label="ANN")
plt.legend(loc='upper right')
plt.show()

# %%
result_snn = [{'Neurons': 10, 'Accuracy': [0.2, 0.18, 0.2, 0.2, 0.19]}, {'Neurons': 50, 'Accuracy': [0.44, 0.44, 0.42, 0.36, 0.44]}, {'Neurons': 100, 'Accuracy': [0.51, 0.54, 0.52, 0.49, 0.41]}, {'Neurons': 200, 'Accuracy': [0.5, 0.66, 0.64, 0.67, 0.62]}, {'Neurons': 400, 'Accuracy': [0.55, 0.66, 0.67, 0.73, 0.69]}, {'Neurons': 800, 'Accuracy': [0.58, 0.6, 0.53, 0.51, 0.54]}]

# %%
y = [1,2,3,4,5]
plt.figure(figsize=(10, 6))
for snn in result_snn:
    plt.plot(y, snn["Accuracy"], label=snn["Neurons"])
plt.title("Comparison SNN performance by layer size")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='upper right')
plt.show()
